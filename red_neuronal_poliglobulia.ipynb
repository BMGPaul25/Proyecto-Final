# %% [markdown]
# #Redes neuronales simples: Poliglobulia

# %% [markdown]
# ##Lectura de datos y creación de dataset

# %%
#Importar la biblioteca pandas
import pandas as pd

#Especificar la ruta del archivo CSV
file_path = './data/data_pol.csv'

#Leer el archivo CSV y crear el dataframe
df = pd.read_csv(file_path, sep=',')

#Mostrar las primeras filas del dataframe para verificar que se haya leído correctamente
df.head()
# Out:
#    HEMATOCRITO  HEMOGLOBINA  GLOB_ROJOS  VOL_CORPUSCULAR_M  HGB_CORPUSCULAR_M  \
# 0         48.2         14.9        5.17               93.1               28.9
# 1         49.8         16.2        5.42               91.9               30.0
# 2         46.3         14.7        4.63              100.0               31.8
# 3         49.0         15.8        5.36               91.4               29.4
# 4         43.9         14.0        4.79               91.7               29.2
#
#    C_HGB_CORPUSCULAR_M  TARGET
# 0                 31.0       0
# 1                 32.6       0
# 2                 31.7       0
# 3                 32.2       0
# 4                 31.8       0

# %% [markdown]
# ##Importación de librerías

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ##Normalización de los datos

# %%
X = df.drop(columns='TARGET')

# %%
y= df['TARGET']

# %%
X.head()
# Out:
#    HEMATOCRITO  HEMOGLOBINA  GLOB_ROJOS  VOL_CORPUSCULAR_M  HGB_CORPUSCULAR_M  \
# 0         48.2         14.9        5.17               93.1               28.9
# 1         49.8         16.2        5.42               91.9               30.0
# 2         46.3         14.7        4.63              100.0               31.8
# 3         49.0         15.8        5.36               91.4               29.4
# 4         43.9         14.0        4.79               91.7               29.2
#
#    C_HGB_CORPUSCULAR_M
# 0                 31.0
# 1                 32.6
# 2                 31.7
# 3                 32.2
# 4                 31.8

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ##Implementación del modelo

# %%
clf = MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=500, alpha=0.0001,
                    solver='adam', verbose=10, random_state=42)

# %%
clf.fit(X_train_scaled, y_train)  # Train the classifier
# Out:
# Iteration 1, loss = 0.48314669
# Iteration 2, loss = 0.42818987
# Iteration 3, loss = 0.38533881
# Iteration 4, loss = 0.35106257
# Iteration 5, loss = 0.32287587
# Iteration 6, loss = 0.29882836
# Iteration 7, loss = 0.27938864
# Iteration 8, loss = 0.26389166
# Iteration 9, loss = 0.25288352
# Iteration 10, loss = 0.24432960
# Iteration 11, loss = 0.23776135
# Iteration 12, loss = 0.23230698
# Iteration 13, loss = 0.22740422
# Iteration 14, loss = 0.22288243
# Iteration 15, loss = 0.21871361
# Iteration 16, loss = 0.21410262
# Iteration 17, loss = 0.20967645
# Iteration 18, loss = 0.20525744
# Iteration 19, loss = 0.20107206
# Iteration 20, loss = 0.19702515
# Iteration 21, loss = 0.19316790
# Iteration 22, loss = 0.18941169
# Iteration 23, loss = 0.18577299
# Iteration 24, loss = 0.18249386
# Iteration 25, loss = 0.17944709
# Iteration 26, loss = 0.17656810
# Iteration 27, loss = 0.17391194
# Iteration 28, loss = 0.17150122
# Iteration 29, loss = 0.16934257
# Iteration 30, loss = 0.16758527
# Iteration 31, loss = 0.16577644
# Iteration 196, loss = 0.12513630
# Iteration 197, loss = 0.12501181
# Iteration 198, loss = 0.12484998
# Iteration 199, loss = 0.12505388
# Iteration 200, loss = 0.12513145
# Iteration 201, loss = 0.12522850
# Iteration 202, loss = 0.12499335
# Iteration 203, loss = 0.12475222
# Iteration 204, loss = 0.12482776
# Iteration 205, loss = 0.12453318
# Iteration 206, loss = 0.12470266
# Iteration 207, loss = 0.12466491
# Iteration 208, loss = 0.12450674
# Iteration 209, loss = 0.12453469
# Iteration 210, loss = 0.12441339
# Iteration 211, loss = 0.12442831
# Iteration 212, loss = 0.12424464
# Iteration 213, loss = 0.12434985
# Iteration 214, loss = 0.12415739
# Iteration 215, loss = 0.12430888
# Iteration 216, loss = 0.12432183
# Iteration 217, loss = 0.12439484
# Iteration 218, loss = 0.12414621
# Iteration 219, loss = 0.12429031
# Iteration 220, loss = 0.12399143
# Iteration 221, loss = 0.12390481
# Iteration 222, loss = 0.12403313
# Iteration 223, loss = 0.12448730
# Iteration 224, loss = 0.12413553
# Iteration 225, loss = 0.12400124
# Iteration 226, loss = 0.12417281
# Iteration 227, loss = 0.12381905
# Iteration 228, loss = 0.12379716
# Iteration 229, loss = 0.12370079
# Iteration 230, loss = 0.12413100
# Iteration 231, loss = 0.12342248
# Iteration 232, loss = 0.12383035
# Iteration 233, loss = 0.12368809
# Iteration 234, loss = 0.12359385
# Iteration 235, loss = 0.12338379
# Iteration 236, loss = 0.12351160
# Iteration 237, loss = 0.12387641
# Iteration 238, loss = 0.12397800
# Iteration 239, loss = 0.12354440
# Iteration 240, loss = 0.12335187
# Iteration 241, loss = 0.12323572
# Iteration 242, loss = 0.12328063
# Iteration 243, loss = 0.12313068
# Iteration 244, loss = 0.12334976
# Iteration 245, loss = 0.12321166
# Iteration 246, loss = 0.12376786
# Iteration 247, loss = 0.12334066
# Iteration 248, loss = 0.12325688
# Iteration 249, loss = 0.12302967
# Iteration 250, loss = 0.12341962
# Iteration 251, loss = 0.12299010
# Iteration 252, loss = 0.12303350
# Iteration 253, loss = 0.12317462
# Iteration 254, loss = 0.12306124
# Iteration 255, loss = 0.12306020
# Iteration 256, loss = 0.12289039
# Iteration 257, loss = 0.12329433
# Iteration 258, loss = 0.12322171
# Iteration 259, loss = 0.12303961
# Iteration 260, loss = 0.12310349
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=500, random_state=42,
#               verbose=10)

# %%
# Predecir en los datos de entrenamiento
y_train_pred = clf.predict(X_train_scaled)

# Predecir en los datos de prueba
y_test_pred = clf.predict(X_test_scaled)

# %% [markdown]
# ##Métricas de evaluación

# %%
y_pred = clf.predict(X_test_scaled)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate recall (sensitivity)
recall = recall_score(y_test, y_pred)
print("Recall (Sensitivity):", recall)

# Calculate F1-score
f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)
# Out:
# Accuracy: 0.9555302166476625
# Precision: 0.8524590163934426
# Recall (Sensitivity): 0.4297520661157025
# F1-Score: 0.5714285714285714

# %%
import numpy as np
scores = cross_val_score(clf, X, y, cv=5)  # 5-fold cross-validation
print("Cross-validation scores: ", scores)
print("Mean cross-validation score: ", np.mean(scores))
# Out:
# Iteration 1, loss = 0.49571201
# Iteration 2, loss = 0.29674303
# Iteration 3, loss = 0.27885426
# Iteration 4, loss = 0.26668879
# Iteration 5, loss = 0.25571618
# Iteration 6, loss = 0.24904299
# Iteration 7, loss = 0.24079696
# Iteration 8, loss = 0.23503813
# Iteration 9, loss = 0.23171502
# Iteration 10, loss = 0.22785810
# Iteration 11, loss = 0.22475258
# Iteration 12, loss = 0.22215589
# Iteration 13, loss = 0.22100436
# Iteration 14, loss = 0.21887159
# Iteration 15, loss = 0.21683476
# Iteration 16, loss = 0.21936613
# Iteration 17, loss = 0.21757527
# Iteration 18, loss = 0.21842926
# Iteration 19, loss = 0.21318923
# Iteration 20, loss = 0.21106323
# Iteration 21, loss = 0.21016993
# Iteration 22, loss = 0.20824368
# Iteration 23, loss = 0.20925909
# Iteration 24, loss = 0.20780422
# Iteration 25, loss = 0.20804651
# Iteration 26, loss = 0.20670970
# Iteration 27, loss = 0.20428885
# Iteration 28, loss = 0.20875483
# Iteration 29, loss = 0.20470380
# Iteration 30, loss = 0.20573928
# Iteration 31, loss = 0.20177362
# Iteration 32, loss = 0.20323377
# Iteration 33, loss = 0.20289824
# Iteration 34, loss = 0.20393066
# Iteration 35, loss = 0.20179457
# Iteration 36, loss = 0.19736597
# Iteration 37, loss = 0.19748631
# Iteration 38, loss = 0.19676388
# Iteration 39, loss = 0.20425220
# Iteration 40, loss = 0.19863326
# Iteration 41, loss = 0.19989479
# Iteration 42, loss = 0.19383453
# Iteration 43, loss = 0.19229605
# Iteration 44, loss = 0.19173501
# Iteration 45, loss = 0.19153989
# Iteration 46, loss = 0.19107258
# Iteration 47, loss = 0.19101401
# Iteration 48, loss = 0.19123865
# Iteration 49, loss = 0.19050329
# Iteration 50, loss = 0.18853755
# Iteration 51, loss = 0.19372914
# Iteration 52, loss = 0.18917782
# Iteration 53, loss = 0.18804943
# Iteration 54, loss = 0.18959017
# Iteration 55, loss = 0.18736164
# Iteration 56, loss = 0.18808974
# Iteration 57, loss = 0.18897039
# Iteration 58, loss = 0.18776919
# Iteration 59, loss = 0.18633873
# Iteration 60, loss = 0.18806691
# Iteration 61, loss = 0.18971922
# Iteration 62, loss = 0.18523285
# Iteration 63, loss = 0.18652387
# Iteration 64, loss = 0.18943463
# Iteration 65, loss = 0.19719179
# Iteration 66, loss = 0.18647611
# Iteration 67, loss = 0.18478082
# Iteration 68, loss = 0.18517427
# Iteration 69, loss = 0.18553369
# Iteration 70, loss = 0.18685042
# Iteration 71, loss = 0.18678044
# Iteration 72, loss = 0.18421736
# Iteration 73, loss = 0.18469490
# Iteration 74, loss = 0.18589860
# Iteration 28, loss = 0.20164080
# Iteration 29, loss = 0.20170613
# Iteration 30, loss = 0.20027267
# Iteration 31, loss = 0.19798943
# Iteration 32, loss = 0.19848876
# Iteration 33, loss = 0.19429296
# Iteration 34, loss = 0.19432995
# Iteration 35, loss = 0.19269540
# Iteration 36, loss = 0.19353449
# Iteration 37, loss = 0.19186503
# Iteration 38, loss = 0.19026006
# Iteration 39, loss = 0.18903455
# Iteration 40, loss = 0.18849725
# Iteration 41, loss = 0.19017628
# Iteration 42, loss = 0.18780302
# Iteration 43, loss = 0.18953238
# Iteration 44, loss = 0.18965655
# Iteration 45, loss = 0.18585350
# Iteration 46, loss = 0.19324859
# Iteration 47, loss = 0.18611000
# Iteration 48, loss = 0.18661882
# Iteration 49, loss = 0.18802658
# Iteration 50, loss = 0.18876618
# Iteration 51, loss = 0.18598233
# Iteration 52, loss = 0.18615149
# Iteration 53, loss = 0.18383242
# Iteration 54, loss = 0.18439654
# Iteration 55, loss = 0.18635613
# Iteration 56, loss = 0.18441338
# Iteration 57, loss = 0.18334253
# Iteration 58, loss = 0.18833651
# Iteration 59, loss = 0.18325316
# Iteration 60, loss = 0.18211345
# Iteration 61, loss = 0.18357953
# Iteration 62, loss = 0.18555350
# Iteration 63, loss = 0.18329870
# Iteration 64, loss = 0.18454724
# Iteration 65, loss = 0.18113689
# Iteration 66, loss = 0.18342687
# Iteration 67, loss = 0.18075600
# Iteration 68, loss = 0.18147149
# Iteration 69, loss = 0.18061645
# Iteration 70, loss = 0.18036167
# Iteration 71, loss = 0.17959403
# Iteration 72, loss = 0.18056791
# Iteration 73, loss = 0.18255810
# Iteration 74, loss = 0.18155504
# Iteration 75, loss = 0.17910616
# Iteration 76, loss = 0.17891167
# Iteration 77, loss = 0.18117398
# Iteration 78, loss = 0.18040628
# Iteration 79, loss = 0.18358946
# Iteration 80, loss = 0.18009324
# Iteration 81, loss = 0.17824308
# Iteration 82, loss = 0.18207478
# Iteration 83, loss = 0.17996810
# Iteration 84, loss = 0.17989846
# Iteration 85, loss = 0.17968537
# Iteration 86, loss = 0.17925016
# Iteration 87, loss = 0.17988185
# Iteration 88, loss = 0.17905913
# Iteration 89, loss = 0.18003145
# Iteration 90, loss = 0.17890809
# Iteration 91, loss = 0.17954628
# Iteration 92, loss = 0.17925479
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Cross-validation scores:  [0.93926433 0.94097519 0.94439692 0.94867408 0.94097519]
# Mean cross-validation score:  0.9428571428571428

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Crear la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Extraer los valores de la matriz de confusión
TN, FP, FN, TP = cm.ravel()

# Visualizar la matriz de confusión con anotaciones
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16})

# Añadir etiquetas para mayor claridad
plt.title('Matriz de Confusión', fontsize=18)
plt.text(0.5, 0.25, f'VN = {TN}', ha='center', va='center', color='white', fontsize=14)
plt.text(1.5, 0.25, f'FP = {FP}', ha='center', va='center', color='black', fontsize=14)
plt.text(0.5, 1.25, f'FN = {FN}', ha='center', va='center', color='black', fontsize=14)
plt.text(1.5, 1.25, f'VP = {TP}', ha='center', va='center', color='white', fontsize=14)

plt.show()

# Imprimir los valores de la matriz de confusión
print(f"Verdaderos Negativos (TN): {TN}")
print(f"Falsos Positivos (FP): {FP}")
print(f"Falsos Negativos (FN): {FN}")
print(f"Verdaderos Positivos (TP): {TP}")
# Out:
# Verdaderos Negativos (TN): 1624
# Falsos Positivos (FP): 9
# Falsos Negativos (FN): 69
# Verdaderos Positivos (TP): 52

# %% [markdown]
# ##Gráfico de pasteles

# %%
import numpy as np
import matplotlib.pyplot as plt

# Supongamos que tienes tus datos originales y predicciones en dos arrays o listas
# Aquí hay datos de ejemplo
datos_originales = np.array(y_test)
datos_predichos = np.array(y_test_pred)

# Contar la cantidad de valores positivos y negativos en ambas variables
originales_positivos = np.sum(datos_originales == 1)
originales_negativos = np.sum(datos_originales == 0)
predichos_positivos = np.sum(datos_predichos == 1)
predichos_negativos = np.sum(datos_predichos == 0)

# Etiquetas para las leyendas
etiquetas = ['Positivos', 'Negativos']

# Datos para los gráficos de pasteles
datos_originales = [originales_positivos, originales_negativos]
datos_predichos = [predichos_positivos, predichos_negativos]

# Configuración de la figura y los subgráficos
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Gráfico de pasteles para los datos originales
axs[0].pie(datos_originales, labels=etiquetas, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Datos Originales')

# Gráfico de pasteles para los datos predichos
axs[1].pie(datos_predichos, labels=etiquetas, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Datos Predichos')

plt.show()

# %% [markdown]
# ##Gráfico de densidad

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Asumiendo que 'y_test' y 'y_pred' son arrays NumPy
feature1 = np.array(y_test)
feature2 = np.array(y_test_pred)

# Gráfico de Densidad (KDE Plot)
plt.figure(figsize=(10, 6))

# Ajustar el parámetro bw para mejorar la suavidad
sns.kdeplot(feature1, shade=True, label='Reales', bw_adjust=0.8, kernel='gau')
sns.kdeplot(feature2, shade=True, label='Predictivos', bw_adjust=0.8, kernel='gau')

plt.title('Gráfico de Densidad de valores reales y predictivos')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_45619/3443233833.py:13: UserWarning:
#
# Support for alternate kernels has been removed; using Gaussian kernel.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(feature1, shade=True, label='Reales', bw_adjust=0.8, kernel='gau')
# /tmp/ipykernel_45619/3443233833.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(feature1, shade=True, label='Reales', bw_adjust=0.8, kernel='gau')
# /home/roof/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_45619/3443233833.py:14: UserWarning:
#
# Support for alternate kernels has been removed; using Gaussian kernel.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(feature2, shade=True, label='Predictivos', bw_adjust=0.8, kernel='gau')
# /tmp/ipykernel_45619/3443233833.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(feature2, shade=True, label='Predictivos', bw_adjust=0.8, kernel='gau')
# /home/roof/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
